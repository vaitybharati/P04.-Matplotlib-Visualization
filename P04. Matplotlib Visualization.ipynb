# %% [markdown]
# # MatPlotLib Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from vega_datasets import data

# %%
cars=data('cars')

# %%
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
cars.columns
# Out:
# Index(['Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
#        'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#       dtype='object')

# %%
cars.axes
# Out:
# [RangeIndex(start=0, stop=406, step=1),
#  Index(['Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
#         'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#        dtype='object')]

# %%
cars.shape
# Out:
# (406, 9)

# %% [markdown]
# ## Table

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).head(10)
# Out:
# Cylinders         3  4  5  6   8
# Miles_per_Gallon
# 9.0               0  0  0  0   1
# 10.0              0  0  0  0   2
# 11.0              0  0  0  0   4
# 12.0              0  0  0  0   6
# 13.0              0  0  0  0  20
# 14.0              0  0  0  0  19
# 14.5              0  0  0  0   1
# 15.0              0  0  0  4  12
# 15.5              0  0  0  0   5
# 16.0              0  0  0  5   8

# %% [markdown]
# ## Plotting two different categories

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).plot()

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).head(10).plot()

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).plot(kind='box')

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).head(10).plot(kind='bar')

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).plot(kind='hist')

# %%
pd.crosstab(cars.Miles_per_Gallon,cars.Cylinders).head(10).plot(kind='hist')

# %% [markdown]
# ## Plotting single category

# %%
cars.Miles_per_Gallon.value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 34.2     1
# 38.1     1
# 37.2     1
# 32.1     1
# 32.7     1
# Name: Miles_per_Gallon, Length: 129, dtype: int64

# %%
f.ax = plt.subplots(figsize=(10,5))
cars.Miles_per_Gallon.value_counts().plot(kind='pie')

# %%
cars.Miles_per_Gallon.head(10).value_counts().plot(kind='pie')

# %%
cars.Miles_per_Gallon.head(10).value_counts().plot(kind='bar')

# %%
cars.Name.value_counts()
# Out:
# ford pinto              6
# amc matador             5
# toyota corolla          5
# ford maverick           5
# toyota corona           4
#                        ..
# dodge aspen 6           1
# mercury monarch ghia    1
# ford escort 2h          1
# mercury lynx l          1
# vw pickup               1
# Name: Name, Length: 311, dtype: int64

# %%
cars.Name.value_counts().plot(kind='pie')

# %%
cars.Name.head(10).value_counts().plot(kind='pie')

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x='Name',y='Miles_per_Gallon',data=cars)

# %%
plt.scatter(x='Name',y='Miles_per_Gallon',data=cars.head(3))

# %%
plt.scatter(cars.Name,cars.Miles_per_Gallon)

# %%
plt.scatter(cars.Name.head(5),cars.Miles_per_Gallon.head(5))

# %% [markdown]
# ## Histogram

# %%
plt.hist(cars.Cylinders)
# Out:
# (array([  4.,   0., 207.,   0.,   3.,   0.,  84.,   0.,   0., 108.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(cars.Cylinders,facecolor='magenta',edgecolor='purple',bins=5)
# Out:
# (array([  4., 207.,   3.,  84., 108.]),
#  array([3., 4., 5., 6., 7., 8.]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# ## Box Plot

# %%
#help(plt.boxplot)

# %%
plt.boxplot(cars.Displacement,vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a10dc47f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a10dc4eb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a10dc4490>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a10dda5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a10dda8b0>],
#  'means': []}

# %%
plt.boxplot(cars.Displacement,vert=False)
plt.xlabel('Displacement')
plt.title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
# Box plot using Seaborn
import seaborn as sns

# %%
sns.boxplot(cars.Miles_per_Gallon.head(10),cars.Acceleration.head(10))

# %% [markdown]
# ## Violin Plot

# %%
#help(plt.violinplot)

# %%
plt.violinplot(cars.Displacement)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x21a13b05b80>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x21a13b05a00>,
#  'cmins': <matplotlib.collections.LineCollection at 0x21a13b05a60>,
#  'cbars': <matplotlib.collections.LineCollection at 0x21a13b112e0>}
